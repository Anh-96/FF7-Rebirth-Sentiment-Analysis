# %%
from helpers import database
import pandas as pd
pd.set_option("display.max_colwidth", None)

# %%
reviews = database.get_reviews(language="english")
sorted_funny = reviews.sort_values("votes_funny", ascending=False)
sorted_funny.head()
# Out:
#               id recommendation_id     author_steamid  author_num_games_owned  \
# 12720  186225328              None  76561198970729867                     194
# 11059  186370125              None  76561198396302192                    1387
# 10335  186491760              None  76561198257508149                     312
# 12713  186226115              None  76561198013757012                       0
# 8356   187110229              None  76561198115713537                       0
#
#        author_num_reviews  author_playtime_forever  \
# 12720                  28                     3727
# 11059                  23                     4389
# 10335                 159                    22889
# 12713                 181                     2440
# 8356                   17                     9958
#
#        author_playtime_last_two_weeks  author_playtime_at_review  \
# 12720                               0                          7
# ...

# %%
sorted_funny.head(10)[["author_steamid", "votes_funny", "review"]]
# Out:
#           author_steamid  votes_funny  \
# 12720  76561198970729867          410
# 11059  76561198396302192          293
# 10335  76561198257508149          120
# 12713  76561198013757012           67
# 8356   76561198115713537           65
# 12718  76561198036173034           60
# 3445   76561198104032233           49
# 12490  76561198388498138           48
# 4323   76561198035606925           47
# 1958   76561198073057644           37
#
# ...
